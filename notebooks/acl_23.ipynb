# %%
import arxiv
import pandas as pd

search = arxiv.Search(
    # filter by containing "acl" in comment
    # cannot filter by "co:acl+2023"
    query = "co:acl",
    max_results = 1000,
    sort_by = arxiv.SortCriterion.SubmittedDate,
)

papers = []
for result in search.results():
    paper = [
        result.entry_id,
        result.updated,
        result.published,
        result.title,
        result.summary,
        result.comment,
        result.primary_category,
    ]
    papers.append(paper)

# %%
cols = ["entry_id", "updated", "published", "title", "summary", "comment", "primary_category"]

df = pd.DataFrame(papers, columns=cols)

# %%
df[df["comment"].str.contains("23")]
# Out:
#                               entry_id                   updated
# 0    http://arxiv.org/abs/2305.15403v1 2023-05-24 17:59:03+00:00  \
# 1    http://arxiv.org/abs/2305.15387v1 2023-05-24 17:48:40+00:00
# 2    http://arxiv.org/abs/2305.15358v1 2023-05-24 17:10:45+00:00
# 3    http://arxiv.org/abs/2305.15344v1 2023-05-24 16:57:04+00:00
# 4    http://arxiv.org/abs/2305.15212v1 2023-05-24 14:51:01+00:00
# ..                                 ...                       ...
# 728  http://arxiv.org/abs/2203.09590v5 2023-05-04 15:49:54+00:00
# 834  http://arxiv.org/abs/2203.05386v2 2023-05-15 18:09:50+00:00
# 899  http://arxiv.org/abs/2202.13047v3 2023-05-18 05:25:49+00:00
# 914  http://arxiv.org/abs/2202.07255v2 2023-05-24 16:03:28+00:00
# 931  http://arxiv.org/abs/2111.00160v3 2023-05-24 02:29:37+00:00
#
#                     published
# 0   2023-05-24 17:59:03+00:00  \
# 1   2023-05-24 17:48:40+00:00
# 2   2023-05-24 17:10:45+00:00
# 3   2023-05-24 16:57:04+00:00
# 4   2023-05-24 14:51:01+00:00
# ..                        ...
# 728 2022-03-17 20:08:25+00:00
# 834 2022-03-10 14:24:19+00:00
# 899 2022-02-26 03:17:08+00:00
# 914 2022-02-15 09:04:14+00:00
# 931 2021-10-30 03:29:47+00:00
#
#                                                  title
# 0    AV-TranSpeech: Audio-Visual Robust Speech-to-S...  \
# 1    Peek Across: Improving Multi-Document Modeling...
# 2    Context-Aware Transformer Pre-Training for Ans...
# 3    Learning Answer Generation using Supervision f...
# 4    Towards Adaptive Prefix Tuning for Parameter-E...
# ..                                                 ...
# 728  ECOLA: Enhanced Temporal Knowledge Embeddings ...
# 834  Faking Fake News for Real Fake News Detection:...
# 899  AugESC: Dialogue Augmentation with Large Langu...
# 914  Enhancing Cross-lingual Prompting with Dual Pr...
# 931  DSEE: Dually Sparsity-embedded Efficient Tunin...
#
#                                                summary
# 0    Direct speech-to-speech translation (S2ST) aim...  \
# 1    The integration of multi-document pre-training...
# 2    Answer Sentence Selection (AS2) is a core comp...
# 3    Recent studies show that sentence-level extrac...
# 4    Fine-tuning large pre-trained language models ...
# ..                                                 ...
# 728  Since conventional knowledge embedding models ...
# 834  Despite recent advances in detecting fake news...
# 899  Crowdsourced dialogue corpora are usually limi...
# 914  Prompting shows promising results in few-shot ...
# 931  Gigantic pre-trained models have become centra...
#
#                                         comment primary_category
# 0                          Accepted to ACL 2023            cs.CL
# 1    Accepted at ACL 2023; camera-ready version            cs.CL
# 2                          Accepted at ACL 2023            cs.CL
# 3                          Accepted at ACL 2023            cs.CL
# 4        Accepted to ACL 2023 (Main conference)            cs.CL
# ..                                          ...              ...
# 728        accepted to Findings of the ACL 2023            cs.CL
# 834                        Accepted by ACL 2023            cs.CL
# 899                        Findings of ACL 2023            cs.CL
# 914                           ACL 2023 Findings            cs.CL
# 931                        Accepted by ACL 2023            cs.LG
#
# [416 rows x 7 columns]

# %%
# comment contains 23 but not 2023
df[df["comment"].str.contains("23") & ~df["comment"].str.contains("2023") ]
# Out:
#                               entry_id                   updated
# 7    http://arxiv.org/abs/2305.15182v1 2023-05-24 14:14:08+00:00  \
# 26   http://arxiv.org/abs/2305.14618v1 2023-05-24 01:35:10+00:00
# 37   http://arxiv.org/abs/2305.13833v1 2023-05-23 08:53:33+00:00
# 215  http://arxiv.org/abs/2305.06407v1 2023-05-10 18:32:32+00:00
# 222  http://arxiv.org/abs/2305.05964v1 2023-05-10 08:16:36+00:00
# 266  http://arxiv.org/abs/2305.03336v1 2023-05-05 07:40:41+00:00
# 367  http://arxiv.org/abs/2212.03813v4 2023-05-23 13:39:39+00:00
# 376  http://arxiv.org/abs/2211.11297v2 2023-05-23 08:40:14+00:00
# 380  http://arxiv.org/abs/2211.08073v4 2023-05-22 11:55:52+00:00
# 705  http://arxiv.org/abs/2203.10316v4 2022-09-15 13:43:33+00:00
#
#                     published
# 7   2023-05-24 14:14:08+00:00  \
# 26  2023-05-24 01:35:10+00:00
# 37  2023-05-23 08:53:33+00:00
# 215 2023-05-10 18:32:32+00:00
# 222 2023-05-10 08:16:36+00:00
# 266 2023-05-05 07:40:41+00:00
# 367 2022-12-07 17:54:59+00:00
# 376 2022-11-21 09:38:59+00:00
# 380 2022-11-15 11:53:55+00:00
# 705 2022-03-19 12:37:16+00:00
#
#                                                  title
# 7    HiTIN: Hierarchy-aware Tree Isomorphism Networ...  \
# 26   Abductive Commonsense Reasoning Exploiting Mut...
# 37   Reducing Sensitivity on Speaker Names for Text...
# 215  Combo of Thinking and Observing for Outside-Kn...
# 222  Interpretable Multimodal Misinformation Detect...
# 266  QCRI at SemEval-2023 Task 3: News Genre, Frami...
# 367      Robustness of Learning from Task Instructions
# 376  In-sample Curriculum Learning by Sequence Comp...
# 380  GLUE-X: Evaluating Natural Language Understand...
# 705  Learning to Reason Deductively: Math Word Prob...
#
#                                                summary
# 7    Hierarchical text classification (HTC) is a ch...  \
# 26   Abductive reasoning aims to find plausible exp...
# 37   Changing speaker names consistently throughout...
# 215  Outside-knowledge visual question answering is...
# 222  Multimodal misinformation on online social pla...
# 266  Misinformation spreading in mainstream and soc...
# 367  Traditional supervised learning mostly works o...
# 376  Curriculum learning has shown promising improv...
# 380  Pre-trained language models (PLMs) are known t...
# 705  Solving math word problems requires deductive ...
#
#                                                comment primary_category
# 7                                   Accepted by ACL'23            cs.CL
# 26                                  accepted at ACL'23            cs.CL
# 37                                  findings of ACL'23            cs.CL
# 215                            ACL-23, Main Conference            cs.CV
# 222  Accepted by Findings of ACL 23. 9 pages, 6 fig...            cs.MM
# 266  Accepted at SemEval-23 (ACL-23, propaganda, di...            cs.CL
# 367                            ACL'23 Finding Accepted            cs.CL
# 376                                             ACL'23            cs.CL
# 380                        Accepted to ACL-23 Findings            cs.CL
# 705  12 pages, 7 figures, ACL-2022, additional expe...            cs.CL

# %%
df_acl_23 = df[df["comment"].str.contains("23")].reset_index(drop=True)

# %%
df_acl_23.to_csv("arxiv_acl_2023.csv")
